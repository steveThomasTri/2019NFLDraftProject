# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from itertools import combinations

# %%
df = pd.read_csv("../DL-Train.csv")
df = df.drop(["year","name","college","position"],1)
df.head()
#377
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0       75.5         274     5.03        19.0          32.5          110.0
# 1       74.6         243     4.64        27.0          37.5          123.0
# 2       76.1         254     4.76         NaN          34.0          118.0
# 3       73.1         244     5.00        19.0          32.0          115.0
# 4       72.1         302     5.41        19.0          25.5           83.0
#
#    shuttle  3cone drafted
# 0     4.83   8.80       Y
# 1     4.49   7.79       N
# 2     4.20   7.64       Y
# 3     4.33   7.81       Y
# 4     5.14   8.42       Y

# %%
Y = df["drafted"]
Y = Y.replace("Y",1)
Y = Y.replace("N",0)

#X = df.drop(['weight_lbs', '3cone', 'Crec', 'Cyds', 'hasbling', 'hasawards', "drafted"], 1)
X = df.drop(["drafted"],1)
X.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0       75.5         274     5.03        19.0          32.5          110.0
# 1       74.6         243     4.64        27.0          37.5          123.0
# 2       76.1         254     4.76         NaN          34.0          118.0
# 3       73.1         244     5.00        19.0          32.0          115.0
# 4       72.1         302     5.41        19.0          25.5           83.0
#
#    shuttle  3cone
# 0     4.83   8.80
# 1     4.49   7.79
# 2     4.20   7.64
# 3     4.33   7.81
# 4     5.14   8.42

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 72.61%

# %%
def accuracyfinder(features):
    accuras = []
    
    Y = features["drafted"]
    Y = Y.replace("Y",1)
    Y = Y.replace("N",0)

    X = features.drop(["drafted"], 1)
    
    columns = X.columns.tolist()
    
    for a in range(1,len(columns)):
        for x in list(combinations(columns,a)):
            
            X = features.drop(["drafted"], 1)
            X = X.drop(list(x),1)
            # split data into train and test sets
            seed = 777
            test_size = 0.30
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

            # fit model on training data
            model = XGBClassifier()
            model.fit(X_train, y_train)

            # make predictions for test data
            y_pred = model.predict(X_test)
            predictions = [round(value) for value in y_pred]

            # evaluate predictions
            accuracy = accuracy_score(y_test, predictions)
            accuras.append(accuracy * 100)
            print("Accuracy: %.2f%%" % (accuracy * 100.0), list(x))
    
    
    print(max(accuras))

# %%
accuracyfinder(df)
# Out:
# Accuracy: 70.96% ['height_in']
# Accuracy: 68.98% ['weight_lbs']
# Accuracy: 69.31% ['40yards']
# Accuracy: 73.93% ['benchpress']
# Accuracy: 71.62% ['vert_leap_in']
# Accuracy: 71.62% ['broad_jump_in']
# Accuracy: 72.28% ['shuttle']
# Accuracy: 72.61% ['3cone']
# Accuracy: 68.65% ['height_in', 'weight_lbs']
# Accuracy: 66.34% ['height_in', '40yards']
# Accuracy: 72.28% ['height_in', 'benchpress']
# Accuracy: 71.62% ['height_in', 'vert_leap_in']
# Accuracy: 71.95% ['height_in', 'broad_jump_in']
# Accuracy: 70.30% ['height_in', 'shuttle']
# Accuracy: 72.61% ['height_in', '3cone']
# Accuracy: 68.65% ['weight_lbs', '40yards']
# Accuracy: 69.31% ['weight_lbs', 'benchpress']
# Accuracy: 68.98% ['weight_lbs', 'vert_leap_in']
# Accuracy: 67.66% ['weight_lbs', 'broad_jump_in']
# Accuracy: 69.97% ['weight_lbs', 'shuttle']
# Accuracy: 70.96% ['weight_lbs', '3cone']
# Accuracy: 68.32% ['40yards', 'benchpress']
# Accuracy: 69.31% ['40yards', 'vert_leap_in']
# Accuracy: 70.30% ['40yards', 'broad_jump_in']
# Accuracy: 67.66% ['40yards', 'shuttle']
# Accuracy: 68.98% ['40yards', '3cone']
# Accuracy: 73.93% ['benchpress', 'vert_leap_in']
# Accuracy: 73.60% ['benchpress', 'broad_jump_in']
# Accuracy: 72.94% ['benchpress', 'shuttle']
# Accuracy: 72.61% ['benchpress', '3cone']
# Accuracy: 69.31% ['vert_leap_in', 'broad_jump_in']
# Accuracy: 70.96% ['vert_leap_in', 'shuttle']
# Accuracy: 73.27% ['vert_leap_in', '3cone']
# Accuracy: 70.30% ['broad_jump_in', 'shuttle']
# Accuracy: 71.95% ['broad_jump_in', '3cone']
# Accuracy: 72.28% ['shuttle', '3cone']
# Accuracy: 67.66% ['height_in', 'weight_lbs', '40yards']
# Accuracy: 68.65% ['height_in', 'weight_lbs', 'benchpress']
# Accuracy: 66.01% ['height_in', 'weight_lbs', 'vert_leap_in']
# Accuracy: 67.66% ['height_in', 'weight_lbs', 'broad_jump_in']
# Accuracy: 68.98% ['height_in', 'weight_lbs', 'shuttle']
# Accuracy: 68.65% ['height_in', 'weight_lbs', '3cone']
# Accuracy: 66.67% ['height_in', '40yards', 'benchpress']
# Accuracy: 67.99% ['height_in', '40yards', 'vert_leap_in']
# Accuracy: 67.00% ['height_in', '40yards', 'broad_jump_in']
# Accuracy: 66.01% ['height_in', '40yards', 'shuttle']
# Accuracy: 68.32% ['height_in', '40yards', '3cone']
# Accuracy: 72.28% ['height_in', 'benchpress', 'vert_leap_in']
# Accuracy: 71.95% ['height_in', 'benchpress', 'broad_jump_in']
# Accuracy: 72.94% ['height_in', 'benchpress', 'shuttle']
# Accuracy: 72.94% ['height_in', 'benchpress', '3cone']
# Accuracy: 70.96% ['height_in', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 72.94% ['height_in', 'vert_leap_in', 'shuttle']
# Accuracy: 72.28% ['height_in', 'vert_leap_in', '3cone']
# Accuracy: 71.29% ['height_in', 'broad_jump_in', 'shuttle']
# Accuracy: 70.30% ['height_in', 'broad_jump_in', '3cone']
# Accuracy: 70.96% ['height_in', 'shuttle', '3cone']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'benchpress']
# Accuracy: 66.67% ['weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 68.32% ['weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 66.67% ['weight_lbs', '40yards', 'shuttle']
# Accuracy: 68.32% ['weight_lbs', '40yards', '3cone']
# Accuracy: 69.31% ['weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 69.64% ['weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 70.96% ['weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 69.64% ['weight_lbs', 'benchpress', '3cone']
# Accuracy: 67.66% ['weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 70.30% ['weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 67.33% ['weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 68.65% ['weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 69.64% ['weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 69.64% ['weight_lbs', 'shuttle', '3cone']
# Accuracy: 68.65% ['40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 69.31% ['40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 68.32% ['40yards', 'benchpress', 'shuttle']
# Accuracy: 68.32% ['40yards', 'benchpress', '3cone']
# Accuracy: 68.65% ['40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 67.99% ['40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 68.98% ['40yards', 'vert_leap_in', '3cone']
# Accuracy: 66.67% ['40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 69.64% ['40yards', 'broad_jump_in', '3cone']
# Accuracy: 69.31% ['40yards', 'shuttle', '3cone']
# Accuracy: 72.94% ['benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 73.93% ['benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 71.62% ['benchpress', 'vert_leap_in', '3cone']
# Accuracy: 70.96% ['benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 72.94% ['benchpress', 'broad_jump_in', '3cone']
# Accuracy: 72.94% ['benchpress', 'shuttle', '3cone']
# Accuracy: 70.96% ['vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 71.62% ['vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 71.95% ['vert_leap_in', 'shuttle', '3cone']
# Accuracy: 72.28% ['broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['height_in', 'weight_lbs', '40yards', 'benchpress']
# Accuracy: 66.01% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 67.33% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 67.33% ['height_in', 'weight_lbs', '40yards', 'shuttle']
# Accuracy: 66.67% ['height_in', 'weight_lbs', '40yards', '3cone']
# Accuracy: 67.99% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 67.99% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 69.31% ['height_in', 'weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 67.33% ['height_in', 'weight_lbs', 'benchpress', '3cone']
# Accuracy: 65.68% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 69.31% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 68.32% ['height_in', 'weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 69.31% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 67.00% ['height_in', 'weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 69.31% ['height_in', 'weight_lbs', 'shuttle', '3cone']
# Accuracy: 68.32% ['height_in', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 67.33% ['height_in', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 67.99% ['height_in', '40yards', 'benchpress', 'shuttle']
# Accuracy: 68.65% ['height_in', '40yards', 'benchpress', '3cone']
# Accuracy: 65.68% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 69.31% ['height_in', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 68.32% ['height_in', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 66.34% ['height_in', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 68.98% ['height_in', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 68.65% ['height_in', '40yards', 'shuttle', '3cone']
# Accuracy: 72.28% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 72.94% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 73.60% ['height_in', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 70.96% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 71.62% ['height_in', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 71.29% ['height_in', 'benchpress', 'shuttle', '3cone']
# Accuracy: 73.60% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 70.63% ['height_in', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 73.60% ['height_in', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 71.95% ['height_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 70.30% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 68.65% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 68.32% ['weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 67.99% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 68.65% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 67.99% ['weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 67.00% ['weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 68.32% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 71.62% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 69.97% ['weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 70.30% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 69.64% ['weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 67.99% ['weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 69.97% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 68.98% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 69.97% ['weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 68.98% ['weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.97% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 68.65% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 68.65% ['40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 68.32% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 70.63% ['40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 69.97% ['40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 67.00% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 68.65% ['40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 70.63% ['40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 69.31% ['40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 72.61% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 72.94% ['benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 72.61% ['benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 72.28% ['benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 71.95% ['vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 66.67% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 68.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 66.67% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 67.99% ['height_in', 'weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 66.01% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 67.33% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 65.35% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 66.67% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 67.33% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 66.67% ['height_in', 'weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 68.65% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 69.64% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 69.64% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 69.97% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 67.00% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 67.33% ['height_in', 'weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 67.99% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 65.68% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.98% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 67.99% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.98% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 67.99% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 67.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 66.34% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 67.99% ['height_in', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 69.64% ['height_in', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 66.34% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.99% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.32% ['height_in', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 68.98% ['height_in', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 73.27% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 70.63% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 73.27% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 72.28% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 71.95% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.97% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 70.96% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 69.97% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 68.98% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 68.65% ['weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 67.66% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.31% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 67.99% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 69.97% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.64% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.31% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.98% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 69.31% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.31% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 70.63% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.65% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 69.64% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 67.99% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 71.95% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 68.65% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 68.32% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 67.99% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 67.99% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 68.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 67.33% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 65.02% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 66.34% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 67.66% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.33% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 69.97% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.67% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.31% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.98% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 69.64% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.68% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 72.94% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.31% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 69.64% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 70.30% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.32% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.65% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.31% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 69.64% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 70.30% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.64% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.65% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 70.30% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.31% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# 73.92739273927393

# %%
Accuracy: 73.93% ['benchpress']
Accuracy: 73.93% ['benchpress', 'vert_leap_in', 'shuttle']
