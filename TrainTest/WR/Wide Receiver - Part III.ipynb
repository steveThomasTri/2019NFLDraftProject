# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

from itertools import combinations

# %%
df = pd.read_csv("WR-Train.csv")
df = df.drop(["year","name","college","position"],1)
df.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0      74.75         220     4.62        13.0          31.5          120.0
# 1      74.13         226     4.60        16.0          35.0          125.0
# 2      72.60         200     4.47         NaN           NaN            NaN
# 3      74.00         196     4.41         NaN          31.0          116.0
# 4      73.50         203     4.50         NaN          36.5          120.0
#
#    shuttle  3cone drafted   Crec    Cyds   CTD  hasbling  allamerican  \
# 0     4.46   6.77       N  120.0  2697.0  18.0         0            0
# 1     4.12   6.87       N  101.0  1800.0  14.0         0            0
# 2      NaN    NaN       Y  131.0  1986.0  10.0         0            0
# 3     4.20   6.90       N   35.0   389.0   3.0         0            0
# 4     4.09   6.83       Y   71.0  1020.0   8.0         0            0
#
#    hasawards
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
Y = df["drafted"]
Y = Y.replace("Y",1)
Y = Y.replace("N",0)

#X = df.drop(['weight_lbs', '3cone', 'Crec', 'Cyds', 'hasbling', 'hasawards', "drafted"], 1)
X = df.drop(["drafted"],1)

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 71.07%

# %%
def accuracyfinder(features):
    accuras = []
    
    Y = features["drafted"]
    Y = Y.replace("Y",1)
    Y = Y.replace("N",0)

    X = features.drop(["drafted"], 1)
    
    columns = X.columns.tolist()
    
    for a in range(1,len(columns)):
        for x in list(combinations(columns,a)):
            
            X = features.drop(["drafted"], 1)
            X = X.drop(list(x),1)
            # split data into train and test sets
            seed = 777
            test_size = 0.30
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

            # fit model on training data
            model = XGBClassifier()
            model.fit(X_train, y_train)

            # make predictions for test data
            y_pred = model.predict(X_test)
            predictions = [round(value) for value in y_pred]

            # evaluate predictions
            accuracy = accuracy_score(y_test, predictions)
            accuras.append(accuracy * 100)
            print("Accuracy: %.2f%%" % (accuracy * 100.0), list(x))
    
    
    print(max(accuras))

# %%
accuracyfinder(df)
# Out:
# Accuracy: 71.07% ['height_in']
# Accuracy: 72.73% ['weight_lbs']
# Accuracy: 63.64% ['40yards']
# Accuracy: 70.25% ['benchpress']
# Accuracy: 72.31% ['vert_leap_in']
# Accuracy: 69.42% ['broad_jump_in']
# Accuracy: 71.49% ['shuttle']
# Accuracy: 71.90% ['3cone']
# Accuracy: 71.90% ['Crec']
# Accuracy: 71.07% ['Cyds']
# Accuracy: 71.07% ['CTD']
# Accuracy: 71.07% ['hasbling']
# Accuracy: 71.07% ['allamerican']
# Accuracy: 71.90% ['hasawards']
# Accuracy: 68.60% ['height_in', 'weight_lbs']
# Accuracy: 61.98% ['height_in', '40yards']
# Accuracy: 66.94% ['height_in', 'benchpress']
# Accuracy: 71.49% ['height_in', 'vert_leap_in']
# Accuracy: 71.90% ['height_in', 'broad_jump_in']
# Accuracy: 68.60% ['height_in', 'shuttle']
# Accuracy: 70.66% ['height_in', '3cone']
# Accuracy: 72.31% ['height_in', 'Crec']
# Accuracy: 69.01% ['height_in', 'Cyds']
# Accuracy: 70.25% ['height_in', 'CTD']
# Accuracy: 71.07% ['height_in', 'hasbling']
# Accuracy: 71.07% ['height_in', 'allamerican']
# ...

# %%
Accuracy: 73.14% ['weight_lbs', '3cone']
Accuracy: 73.55% ['vert_leap_in', 'Crec']
Accuracy: 74.38% ['weight_lbs', '3cone', 'hasawards']
Accuracy: 74.79% ['weight_lbs', 'broad_jump_in', '3cone', 'Crec']
Accuracy: 74.79% ['vert_leap_in', 'broad_jump_in', 'Crec', 'hasawards']
Accuracy: 74.79% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'Crec', 'Cyds']
Accuracy: 74.79% ['vert_leap_in', 'broad_jump_in', 'Crec', 'allamerican', 'hasawards']
Accuracy: 74.79% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', 'Crec', 'hasawards']
Accuracy: 74.79% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'Crec', 'Cyds', 'hasbling']
Accuracy: 74.79% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'Crec', 'Cyds', 'hasbling', 'allamerican']
Accuracy: 75.21% ['weight_lbs', 'vert_leap_in', 'shuttle', '3cone', 'Crec', 'CTD', 'hasbling', 'hasawards']

# %%
#1st iteration
X = X.drop([item for item in X.columns.tolist() if item in ['weight_lbs', 'vert_leap_in', 'shuttle', '3cone', 'Crec', 'CTD', 'hasbling', 'hasawards']], 1)
X.head()
# Out:
#    height_in  40yards  benchpress  broad_jump_in    Cyds  allamerican
# 0      74.75     4.62        13.0          120.0  2697.0            0
# 1      74.13     4.60        16.0          125.0  1800.0            0
# 2      72.60     4.47         NaN            NaN  1986.0            0
# 3      74.00     4.41         NaN          116.0   389.0            0
# 4      73.50     4.50         NaN          120.0  1020.0            0

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 75.21%

# %%
accur = 0

for learning_rate in [.1,.01,.001,.0001]:
    for n_estimators in [100,200,300,400,500]:
        for max_depth in [2,3,5,7,9,11]:
            for min_child_weight in [1,3,5,7]:
                for gamma in [0,.1,.2,.3,.4,.5]:
                    for colsample_bytree in [1,.7,.5,.4,.3]:
                        # split data into train and test sets
                        seed = 777
                        test_size = 0.30
                        X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

                        # fit model on training data
                        model = XGBClassifier(colsample_bytree=colsample_bytree,gamma=gamma, learning_rate=learning_rate, n_estimators=n_estimators, max_depth=max_depth, min_child_weight=min_child_weight)
                        model.fit(X_train, y_train)

                        # make predictions for test data
                        y_pred = model.predict(X_test)
                        predictions = [round(value) for value in y_pred]

                        # evaluate predictions
                        accuracy = accuracy_score(y_test, predictions)
                        print("Accuracy: %.2f%%" % (accuracy * 100.0), learning_rate,n_estimators,max_depth, min_child_weight, gamma, colsample_bytree)
                        #.1 and 200

                        if ((accuracy * 100) > accur):
                            accur = accuracy * 100

print(accur)
# Out:
# Accuracy: 72.73% 0.1 100 2 1 0 1
# Accuracy: 72.73% 0.1 100 2 1 0 0.7
# Accuracy: 71.49% 0.1 100 2 1 0 0.5
# Accuracy: 70.66% 0.1 100 2 1 0 0.4
# Accuracy: 71.07% 0.1 100 2 1 0 0.3
# Accuracy: 72.73% 0.1 100 2 1 0.1 1
# Accuracy: 72.73% 0.1 100 2 1 0.1 0.7
# Accuracy: 71.49% 0.1 100 2 1 0.1 0.5
# Accuracy: 70.66% 0.1 100 2 1 0.1 0.4
# Accuracy: 71.07% 0.1 100 2 1 0.1 0.3
# Accuracy: 72.73% 0.1 100 2 1 0.2 1
# Accuracy: 72.73% 0.1 100 2 1 0.2 0.7
# Accuracy: 71.49% 0.1 100 2 1 0.2 0.5
# Accuracy: 71.07% 0.1 100 2 1 0.2 0.4
# Accuracy: 71.07% 0.1 100 2 1 0.2 0.3
# Accuracy: 72.73% 0.1 100 2 1 0.3 1
# Accuracy: 73.14% 0.1 100 2 1 0.3 0.7
# Accuracy: 71.49% 0.1 100 2 1 0.3 0.5
# Accuracy: 71.07% 0.1 100 2 1 0.3 0.4
# Accuracy: 71.49% 0.1 100 2 1 0.3 0.3
# Accuracy: 72.73% 0.1 100 2 1 0.4 1
# Accuracy: 73.55% 0.1 100 2 1 0.4 0.7
# Accuracy: 70.66% 0.1 100 2 1 0.4 0.5
# Accuracy: 70.66% 0.1 100 2 1 0.4 0.4
# Accuracy: 71.90% 0.1 100 2 1 0.4 0.3
# Accuracy: 73.55% 0.1 100 2 1 0.5 1
# ...

# %%
Accuracy: 75.21% 0.1 100 3 1 0 1
