# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

from itertools import combinations

# %%
df = pd.read_csv("../WR-Train.csv")
df = df.drop(["year","name","college","position"],1)
df.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0      71.63         160     4.47         NaN          30.5          115.0
# 1      68.80         161     4.65         NaN          30.5          115.0
# 2      68.10         164     4.51         NaN          32.5          117.0
# 3      71.00         166     4.53         NaN          34.0          113.0
# 4      69.40         170     4.63         NaN          31.5          116.0
#
#    shuttle  3cone drafted
# 0      NaN   6.97       N
# 1     4.14   7.36       N
# 2     4.22   7.34       N
# 3     4.16    NaN       N
# 4     4.29   7.34       N

# %%
print(len(df))

#806 Records
# Out:
# 806

# %%
Y = df["drafted"]
Y = Y.replace("Y",1)
Y = Y.replace("N",0)

#X = df.drop(['weight_lbs', '3cone', 'Crec', 'Cyds', 'hasbling', 'hasawards', "drafted"], 1)
X = df.drop(["drafted"],1)

# %%
#X = X.drop([item for item in X.columns.tolist() if item not in ["40yards","height_in","3cone",'CTD']], 1)
X["benchpress"] = X["benchpress"].fillna(value=0)
X["vert_leap_in"] = X["vert_leap_in"].fillna(value=0)
X["broad_jump_in"] = X["broad_jump_in"].fillna(value=0)
X["Crec"] = X["Crec"].fillna(value=0)
X["Cyds"] = X["Cyds"].fillna(value=0)
X["CTD"] = X["CTD"].fillna(value=0)
X["shuttle"] = X["shuttle"].fillna(value=100)
X["3cone"] = X["3cone"].fillna(value=100)
X["40yards"] = X["40yards"].fillna(value=100)
X.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0      71.63         160     4.47         0.0          30.5          115.0
# 1      68.80         161     4.65         0.0          30.5          115.0
# 2      68.10         164     4.51         0.0          32.5          117.0
# 3      71.00         166     4.53         0.0          34.0          113.0
# 4      69.40         170     4.63         0.0          31.5          116.0
#
#    shuttle   3cone   Crec    Cyds  Cavg   CTD  games
# 0   100.00    6.97   98.0  1511.0  15.4  12.0   49.0
# 1     4.14    7.36  188.0  2956.0  15.7  15.0   48.0
# 2     4.22    7.34    0.0     0.0   NaN   0.0    NaN
# 3     4.16  100.00    0.0     0.0   NaN   0.0    NaN
# 4     4.29    7.34    0.0     0.0   NaN   0.0    NaN

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 67.36%

# %%
def accuracyfinder(features):
    accuras = []
    
    Y = features["drafted"]
    Y = Y.replace("Y",1)
    Y = Y.replace("N",0)

    X = features.drop(["drafted"], 1)
    
    columns = X.columns.tolist()
    
    for a in range(1,len(columns)):
        for x in list(combinations(columns,a)):
            
            X = features.drop(["drafted"], 1)
            X = X.drop(list(x),1)
            # split data into train and test sets
            seed = 777
            test_size = 0.30
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

            # fit model on training data
            model = XGBClassifier()
            model.fit(X_train, y_train)

            # make predictions for test data
            y_pred = model.predict(X_test)
            predictions = [round(value) for value in y_pred]

            # evaluate predictions
            accuracy = accuracy_score(y_test, predictions)
            accuras.append(accuracy * 100)
            print("Accuracy: %.2f%%" % (accuracy * 100.0), list(x))
    
    
    print(max(accuras))

# %%
accuracyfinder(df)
# Out:
# Accuracy: 68.18% ['height_in']
# Accuracy: 70.25% ['weight_lbs']
# Accuracy: 63.22% ['40yards']
# Accuracy: 69.01% ['benchpress']
# Accuracy: 67.77% ['vert_leap_in']
# Accuracy: 69.83% ['broad_jump_in']
# Accuracy: 66.94% ['shuttle']
# Accuracy: 63.64% ['3cone']
# Accuracy: 65.70% ['height_in', 'weight_lbs']
# Accuracy: 63.22% ['height_in', '40yards']
# Accuracy: 67.36% ['height_in', 'benchpress']
# Accuracy: 67.36% ['height_in', 'vert_leap_in']
# Accuracy: 68.60% ['height_in', 'broad_jump_in']
# Accuracy: 66.53% ['height_in', 'shuttle']
# Accuracy: 66.94% ['height_in', '3cone']
# Accuracy: 64.88% ['weight_lbs', '40yards']
# Accuracy: 70.25% ['weight_lbs', 'benchpress']
# Accuracy: 69.83% ['weight_lbs', 'vert_leap_in']
# Accuracy: 69.01% ['weight_lbs', 'broad_jump_in']
# Accuracy: 68.18% ['weight_lbs', 'shuttle']
# Accuracy: 65.29% ['weight_lbs', '3cone']
# Accuracy: 63.64% ['40yards', 'benchpress']
# Accuracy: 62.40% ['40yards', 'vert_leap_in']
# Accuracy: 65.70% ['40yards', 'broad_jump_in']
# Accuracy: 64.46% ['40yards', 'shuttle']
# Accuracy: 60.33% ['40yards', '3cone']
# Accuracy: 67.36% ['benchpress', 'vert_leap_in']
# Accuracy: 67.36% ['benchpress', 'broad_jump_in']
# Accuracy: 67.77% ['benchpress', 'shuttle']
# Accuracy: 66.53% ['benchpress', '3cone']
# Accuracy: 68.60% ['vert_leap_in', 'broad_jump_in']
# Accuracy: 66.12% ['vert_leap_in', 'shuttle']
# Accuracy: 67.36% ['vert_leap_in', '3cone']
# Accuracy: 67.36% ['broad_jump_in', 'shuttle']
# Accuracy: 66.53% ['broad_jump_in', '3cone']
# Accuracy: 64.46% ['shuttle', '3cone']
# Accuracy: 61.98% ['height_in', 'weight_lbs', '40yards']
# Accuracy: 68.60% ['height_in', 'weight_lbs', 'benchpress']
# Accuracy: 67.77% ['height_in', 'weight_lbs', 'vert_leap_in']
# Accuracy: 67.36% ['height_in', 'weight_lbs', 'broad_jump_in']
# Accuracy: 65.70% ['height_in', 'weight_lbs', 'shuttle']
# Accuracy: 64.88% ['height_in', 'weight_lbs', '3cone']
# Accuracy: 63.22% ['height_in', '40yards', 'benchpress']
# Accuracy: 60.33% ['height_in', '40yards', 'vert_leap_in']
# Accuracy: 65.29% ['height_in', '40yards', 'broad_jump_in']
# Accuracy: 64.88% ['height_in', '40yards', 'shuttle']
# Accuracy: 59.50% ['height_in', '40yards', '3cone']
# Accuracy: 65.70% ['height_in', 'benchpress', 'vert_leap_in']
# Accuracy: 67.77% ['height_in', 'benchpress', 'broad_jump_in']
# Accuracy: 66.12% ['height_in', 'benchpress', 'shuttle']
# Accuracy: 67.77% ['height_in', 'benchpress', '3cone']
# Accuracy: 67.36% ['height_in', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 67.77% ['height_in', 'vert_leap_in', 'shuttle']
# Accuracy: 67.77% ['height_in', 'vert_leap_in', '3cone']
# Accuracy: 67.36% ['height_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.36% ['height_in', 'broad_jump_in', '3cone']
# Accuracy: 67.36% ['height_in', 'shuttle', '3cone']
# Accuracy: 63.64% ['weight_lbs', '40yards', 'benchpress']
# Accuracy: 64.46% ['weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 67.36% ['weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 66.94% ['weight_lbs', '40yards', 'shuttle']
# Accuracy: 60.74% ['weight_lbs', '40yards', '3cone']
# Accuracy: 68.60% ['weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 70.25% ['weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 68.60% ['weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 66.94% ['weight_lbs', 'benchpress', '3cone']
# Accuracy: 72.31% ['weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 70.66% ['weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 64.46% ['weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 69.01% ['weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 67.77% ['weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 67.77% ['weight_lbs', 'shuttle', '3cone']
# Accuracy: 62.40% ['40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 64.05% ['40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 64.88% ['40yards', 'benchpress', 'shuttle']
# Accuracy: 58.26% ['40yards', 'benchpress', '3cone']
# Accuracy: 62.81% ['40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 62.81% ['40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.33% ['40yards', 'vert_leap_in', '3cone']
# Accuracy: 64.46% ['40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 61.16% ['40yards', 'broad_jump_in', '3cone']
# Accuracy: 60.33% ['40yards', 'shuttle', '3cone']
# Accuracy: 66.94% ['benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 66.12% ['benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 66.94% ['benchpress', 'vert_leap_in', '3cone']
# Accuracy: 66.53% ['benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 67.77% ['benchpress', 'broad_jump_in', '3cone']
# Accuracy: 65.29% ['benchpress', 'shuttle', '3cone']
# Accuracy: 67.36% ['vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.01% ['vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 64.46% ['vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.53% ['broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.40% ['height_in', 'weight_lbs', '40yards', 'benchpress']
# Accuracy: 61.16% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 64.46% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 64.88% ['height_in', 'weight_lbs', '40yards', 'shuttle']
# Accuracy: 60.33% ['height_in', 'weight_lbs', '40yards', '3cone']
# Accuracy: 69.42% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 68.18% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 65.70% ['height_in', 'weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 66.53% ['height_in', 'weight_lbs', 'benchpress', '3cone']
# Accuracy: 69.01% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 69.42% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 68.18% ['height_in', 'weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 66.94% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 66.53% ['height_in', 'weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 66.94% ['height_in', 'weight_lbs', 'shuttle', '3cone']
# Accuracy: 64.46% ['height_in', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 65.70% ['height_in', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 64.05% ['height_in', '40yards', 'benchpress', 'shuttle']
# Accuracy: 61.57% ['height_in', '40yards', 'benchpress', '3cone']
# Accuracy: 62.40% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 63.22% ['height_in', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 56.61% ['height_in', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 66.53% ['height_in', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 57.02% ['height_in', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 58.26% ['height_in', '40yards', 'shuttle', '3cone']
# Accuracy: 69.01% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 68.18% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 65.70% ['height_in', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 67.77% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 66.12% ['height_in', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 66.94% ['height_in', 'benchpress', 'shuttle', '3cone']
# Accuracy: 68.60% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 66.12% ['height_in', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 66.94% ['height_in', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 64.05% ['height_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 63.22% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 64.88% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 65.29% ['weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 60.33% ['weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 63.64% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 63.64% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 61.57% ['weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 66.12% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 61.98% ['weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 59.50% ['weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 68.60% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 70.25% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 67.77% ['weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 69.42% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 69.42% ['weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 66.53% ['weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 68.18% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.36% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 69.42% ['weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 69.01% ['weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.98% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 61.16% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 59.92% ['40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 65.29% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 61.16% ['40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 59.50% ['40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 63.22% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.74% ['40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.57% ['40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 61.16% ['40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 66.94% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 68.60% ['benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 65.29% ['benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 64.46% ['benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 66.53% ['vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 65.29% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 64.05% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 57.85% ['height_in', 'weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 61.57% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 62.40% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.74% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 65.70% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 56.20% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 59.50% ['height_in', 'weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 68.18% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 68.60% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 66.12% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 69.42% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 69.83% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 66.12% ['height_in', 'weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 69.42% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 66.12% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.60% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.94% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 63.64% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 64.05% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 58.68% ['height_in', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 66.12% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 61.98% ['height_in', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 59.50% ['height_in', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 64.46% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 61.57% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 62.81% ['height_in', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 61.98% ['height_in', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 67.77% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.77% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.18% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 68.18% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 66.94% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 64.46% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 61.57% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 59.50% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 65.29% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 62.40% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 59.50% ['weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 61.57% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 61.16% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.57% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 61.57% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 68.18% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 68.18% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 67.77% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 67.77% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.42% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.98% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 58.68% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.16% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 61.16% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.57% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.70% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.81% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 61.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 64.46% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 65.70% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 56.61% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 61.16% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 65.29% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.33% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 62.81% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.74% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 67.77% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.77% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 68.60% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 67.77% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.70% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.40% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 61.16% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.98% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 62.40% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 63.22% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.83% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.16% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 57.02% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 59.09% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 61.16% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.81% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 67.36% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 59.92% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 59.09% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 61.98% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 62.81% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 59.50% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.40% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.83% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.40% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.16% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# 72.31404958677686
