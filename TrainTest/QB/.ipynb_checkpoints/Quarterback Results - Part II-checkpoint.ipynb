# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from itertools import combinations

# %%
df = pd.read_csv("QB-Train.csv")
#df = df.drop(["year","name","college","position"],1)
df.head()
#377
# Out:
#    year              name         college position  height_in  weight_lbs  \
# 0  2007        zac taylor        Nebraska       QB      74.38         216
# 1  2010      zac robinson  Oklahoma State       QB      74.50         214
# 2  2013        zac dysert      Miami (OH)       QB      75.00         227
# 3  1997  wally richardson      Penn State       QB      76.40         221
# 4  2006       vince young           Texas       QB      76.60         229
#
#    40yards  benchpress  vert_leap_in  broad_jump_in  shuttle  3cone drafted
# 0     5.08         NaN          30.5          110.0     4.60   7.39       N
# 1     4.68         NaN          35.0          110.0     4.40   7.24       Y
# 2     4.81         NaN           NaN            NaN      NaN    NaN       Y
# 3     4.95         NaN          31.0          109.0     4.47   7.97       Y
# 4     4.48         NaN           NaN            NaN      NaN    NaN       Y

# %%
df["hasstats"] = ""

# %%
from splinter import Browser
from sys import platform
import os
import csv
import re

executable_path = None

if platform == "linux" or platform == "linux2":
    executable_path = {'executable_path': os.path.join("binaries", "chromedriver-linux")}
elif platform == "darwin":
    executable_path = {'executable_path': os.path.join("binaries", "chromedriver-mac")}
elif platform == "win32":
    executable_path = {'executable_path': os.path.join("..","..","binaries", "chromedriver-windows.exe")}

browser = Browser('chrome', **executable_path, headless=False)

# %%
for index, row in df.iterrows():
    if (df.loc[index,"hasstats"] == ""):
        x = row["name"]
        browser.visit(f"https://www.sports-reference.com/cfb/search/search.fcgi?hint=&search={x}")
        if (len(browser.find_by_css("table#passing")) > 0):
            #elem = len(browser.find_by_css("td[data-stat='rec']"))
            #testit.loc[index, "Crec"] = browser.find_by_css("td[data-stat='rec']")[elem-1].text
            #testit.loc[index, "Cyds"] = browser.find_by_css("td[data-stat='rec_yds']")[elem-1].text
            #testit.loc[index, "CTD"] = browser.find_by_css("td[data-stat='rec_td']")[elem-1].text
            df.loc[index,"hasstats"] = 1
        elif (len(browser.find_by_css("div.search-item")) == 0):
            df.loc[index,"hasstats"] = 0
        else:
            listed = browser.find_by_css("div.search-item")
            
            print()
            
            for x in listed:
                if (re.sub(r'\(.*\)', "", row["college"]).strip() in x.find_by_css("div.search-item-league").text):
                    x.find_by_css("div.search-item-name a").click()
                    if (len(browser.find_by_css("table#passing")) > 0):
                        #elem = len(browser.find_by_css("td[data-stat='rec']"))
                        #testit.loc[index, "Crec"] = browser.find_by_css("td[data-stat='rec']")[elem-1].text
                        #testit.loc[index, "Cyds"] = browser.find_by_css("td[data-stat='rec_yds']")[elem-1].text
                        #testit.loc[index, "CTD"] = browser.find_by_css("td[data-stat='rec_td']")[elem-1].text
                        df.loc[index,"hasstats"] = 1
                        break
                    else:
                        df.loc[index,"hasstats"] = 0
                        break
                else:
                    df.loc[index,"hasstats"] = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      39         try:
# ---> 40             return super(ElementList, self).__getitem__(index)
#      41         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\splinter\element_list.py in __getattr__(self, name)
#      73         try:
# ---> 74             return getattr(self.first, name)
#      75         except (ElementDoesNotExist, AttributeError):
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\splinter\element_list.py in first(self)
#      54         """
# ---> 55         return self[0]
#      56
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      43                 u'no elements could be found with {0} "{1}"'.format(
# ---> 44                     self.find_by, self.query
#      45                 )
#
# ElementDoesNotExist: no elements could be found with css "div.search-item-league"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-536606b8fbd8> in <module>
#      17
#      18             for x in listed:
# ---> 19                 if (re.sub(r'\(.*\)', "", row["college"]).strip() in x.find_by_css("div.search-item-league").text):
#      20                     x.find_by_css("div.search-item-name a").click()
#      21                     if (len(browser.find_by_css("table#passing")) > 0):
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\splinter\element_list.py in __getattr__(self, name)
#      76             raise AttributeError(
#      77                 u"'{0}' object has no attribute '{1}'".format(
# ---> 78                     self.__class__.__name__, name
#      79                 )
#      80             )
#
# AttributeError: 'ElementList' object has no attribute 'text'

# %%
df
# Out:
#      year               name                 college position  height_in  \
# 0    1997      jim arellanes       Frenso State (CA)       QB      75.10
# 1    1997        mike cherry       Murray State (KY)       QB      75.90
# 2    1997     chuck clements                 Houston       QB      74.60
# 3    1997    marcus crandell      East Carolina (NC)       QB      71.40
# 4    1997        jason davis  Western State Colorado       QB      75.50
# 5    1997         koy detmer                Colorado       QB      72.90
# 6    1997  jim druckenmiller           Virginia Tech       QB      76.60
# 7    1997   lance funderburk     Valdosta State (GA)       QB      76.40
# 8    1997       jason martin          Louisiana Tech       QB      74.40
# 9    1997         brad otton     Southern California       QB      78.10
# 10   1997       jake plummer           Arizona State       QB      74.30
# 11   1997   wally richardson              Penn State       QB      76.40
# 12   1997    steve sarkisian           Brigham Young       QB      72.40
# 13   1997     danny wuerffel                 Florida       QB      73.80
# 14   1998      charlie batch        Eastern Michigan       QB      73.90
# 15   1998         thad busby           Florida State       QB      74.10
# 16   1998       ryan clement              Miami (FL)       QB      73.00
# 17   1998        john dutton        Nevada Las Vegas       QB      75.90
# 18   1998      shane fortney           Northern Iowa       QB      73.60
# 19   1998       dan gonzalez      East Carolina (NC)       QB      74.60
# 20   1998        paul kaiser        Central Missouri       QB      74.60
# 21   1998        chris mccoy                    Navy       QB      69.80
# 22   1998      mike mcqueary              Penn State       QB      76.30
# 23   1998         ron powlus              Notre Dame       QB      73.60
# 24   1998        cory sauter               Minnesota       QB      76.10
# 25   1998       matt sherman                    Iowa       QB      73.90
# 26   1999      todd bandhaur              Iowa State       QB      75.00
# 27   1999     michael bishop            Kansas State       QB      73.00
# 28   1999       aaron brooks                Virginia       QB      75.50
# 29   1999          mike cook     William & Mary (VA)       QB      71.60
# ..    ...                ...                     ...      ...        ...
# 347  2017        jerod evans           Virginia Tech       QB      74.63
# 348  2017         chad kelly             Mississippi       QB      74.00
# 349  2017      deshone kizer              Notre Dame       QB      76.13
# 350  2017      mitch leidner               Minnesota       QB      75.38
# 351  2017        sefo liufau                Colorado       QB      75.38
# 352  2017    patrick mahomes              Texas Tech       QB      74.13
# 353  2017    nathan peterman              Pittsburgh       QB      74.63
# 354  2017        cooper rush        Central Michigan       QB      74.63
# 348         224      NaN         NaN           NaN            NaN     4.08
# 349         233     4.83         NaN          30.5          107.0     4.53
# 350         226     4.93         NaN          34.5          123.0     4.25
# 351         232     5.08         NaN          27.0          105.0     4.45
# 352         225     4.80         NaN          30.0          114.0     4.08
# 353         226     4.82         NaN          31.0          110.0     4.31
# 354         228     4.93         NaN          27.0          105.0     4.47
# 355         230      NaN         NaN           NaN            NaN     4.31
# 356         222     4.67         NaN          27.5          116.0     4.25
# 357         221     4.66         NaN          32.5          119.0     4.31
# 358         229     4.79         NaN          33.0          118.0      NaN
# 359         210     4.81         NaN          29.5          112.0     4.48
# 360         237     4.75         NaN          33.5          119.0     4.40
# 361         224     4.70         NaN          30.0          108.0     4.44
# 362         218     4.95        16.0          31.0          112.0     4.33
# 363         221     4.85         NaN          26.5          105.0     4.40
# 364         222     4.76         NaN          30.5          114.0     4.37
# 365         215      NaN         NaN          26.5          103.0      NaN
# 366         212     4.98         NaN          29.0          110.0     4.40
# 367         214     4.63         NaN           NaN          112.0     4.57
# 368         222     4.81         NaN          31.0          113.0     4.07
# 369         218     4.98         NaN          32.0          115.0     4.41
# 370         230     4.90         NaN          29.5          106.0     4.53
# 371         215     4.84         NaN          29.0          111.0     4.28
# 372         226     4.92         NaN          31.0          111.0     4.28
# 373         235     4.90         NaN          26.0            NaN      NaN
# 374         220     4.88         NaN          28.5          101.0     4.32
# 375         224     5.09         NaN          27.0           96.0     4.40
# 376         213     4.79         NaN          31.5          103.0     4.15
#
#      3cone drafted hasstats
# 0     8.03       N        1
# 1     7.80       Y        1
# 2     7.69       Y        1
# 3     8.25       N        1
# 4     7.85       N        0
# 5     7.79       Y        1
# 6     7.92       Y        1
# 7      NaN       N        0
# 8     7.81       N        1
# 9     7.54       N        1
# 10    7.30       Y        1
# 11    7.97       Y        1
# 12    8.16       N        1
# 13    7.69       Y        1
# 14    7.60       Y        1
# 15     NaN       N        1
# 16    7.85       N        1
# 17    7.55       Y        0
# 18    7.74       N        1
# 19    7.58       N        1
# 20    7.25       N        0
# 21     NaN       N        1
# 22    7.79       N        1
# 23    7.53       N        1
# 24    7.45       N        1
# 25    7.68       N        1
# 26    7.66       N        0
# 27    7.63       Y        1
# 28    7.52       Y        1
# 29    7.29       N        0
# ..     ...     ...      ...
# 347    NaN       N
# 348    NaN       Y
# 349   7.40       Y
# 350   6.96       N
# 351   7.32       N
# 352   6.88       Y
# 353   7.14       Y
# 354   7.23       N
# 355    NaN       N
# 356   6.87       N
# 357   6.95       Y
# 358   6.92       Y
# 359   7.18       N
# 360   6.90       Y
# 361   7.38       N
# 362   7.15       N
# 363   6.96       Y
# 364   7.09       Y
# 365    NaN       Y
# 366   6.96       N
# 367   6.81       N
# 368   6.95       Y
# 369   7.00       Y
# 370   7.49       N
# 371   7.00       Y
# 372   7.09       Y
# 373    NaN       Y
# 374   7.28       N
# 375   7.40       Y
# 376   6.94       Y
#
# [377 rows x 14 columns]
