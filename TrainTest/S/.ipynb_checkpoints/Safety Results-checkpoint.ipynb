# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from itertools import combinations

# %%
df = pd.read_csv("../S-Train.csv")
df = df.drop(["year","name","college","position"],1)
df.head()
#377
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0       72.0         205     4.78         NaN          34.0          116.0
# 1       70.6         190     4.80        12.0          32.5          111.0
# 2       72.4         190     4.66         9.0          33.5          115.0
# 3       73.3         200      NaN        16.0           NaN            NaN
# 4       72.9         213     5.02        14.0          28.5            NaN
#
#    shuttle  3cone drafted
# 0     4.22   7.27       N
# 1     4.05   7.14       Y
# 2     4.35   7.63       N
# 3      NaN    NaN       Y
# 4     4.36   7.45       N

# %%
Y = df["drafted"]
Y = Y.replace("Y",1)
Y = Y.replace("N",0)

#X = df.drop(['weight_lbs', '3cone', 'Crec', 'Cyds', 'hasbling', 'hasawards', "drafted"], 1)
X = df.drop(["drafted"],1)
X.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0       72.0         205     4.78         NaN          34.0          116.0
# 1       70.6         190     4.80        12.0          32.5          111.0
# 2       72.4         190     4.66         9.0          33.5          115.0
# 3       73.3         200      NaN        16.0           NaN            NaN
# 4       72.9         213     5.02        14.0          28.5            NaN
#
#    shuttle  3cone
# 0     4.22   7.27
# 1     4.05   7.14
# 2     4.35   7.63
# 3      NaN    NaN
# 4     4.36   7.45

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 62.58%

# %%
def accuracyfinder(features):
    accuras = []
    
    Y = features["drafted"]
    Y = Y.replace("Y",1)
    Y = Y.replace("N",0)

    X = features.drop(["drafted"], 1)
    
    columns = X.columns.tolist()
    
    for a in range(1,len(columns)):
        for x in list(combinations(columns,a)):
            
            X = features.drop(["drafted"], 1)
            X = X.drop(list(x),1)
            # split data into train and test sets
            seed = 777
            test_size = 0.30
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

            # fit model on training data
            model = XGBClassifier()
            model.fit(X_train, y_train)

            # make predictions for test data
            y_pred = model.predict(X_test)
            predictions = [round(value) for value in y_pred]

            # evaluate predictions
            accuracy = accuracy_score(y_test, predictions)
            accuras.append(accuracy * 100)
            print("Accuracy: %.2f%%" % (accuracy * 100.0), list(x))
    
    
    print(max(accuras))

# %%
accuracyfinder(df)
# Out:
# Accuracy: 62.58% ['height_in']
# Accuracy: 65.16% ['weight_lbs']
# Accuracy: 61.94% ['40yards']
# Accuracy: 63.23% ['benchpress']
# Accuracy: 63.87% ['vert_leap_in']
# Accuracy: 63.23% ['broad_jump_in']
# Accuracy: 64.52% ['shuttle']
# Accuracy: 63.23% ['3cone']
# Accuracy: 61.94% ['height_in', 'weight_lbs']
# Accuracy: 61.29% ['height_in', '40yards']
# Accuracy: 64.52% ['height_in', 'benchpress']
# Accuracy: 64.52% ['height_in', 'vert_leap_in']
# Accuracy: 65.81% ['height_in', 'broad_jump_in']
# Accuracy: 61.29% ['height_in', 'shuttle']
# Accuracy: 62.58% ['height_in', '3cone']
# Accuracy: 60.65% ['weight_lbs', '40yards']
# Accuracy: 67.10% ['weight_lbs', 'benchpress']
# Accuracy: 65.16% ['weight_lbs', 'vert_leap_in']
# Accuracy: 66.45% ['weight_lbs', 'broad_jump_in']
# Accuracy: 67.74% ['weight_lbs', 'shuttle']
# Accuracy: 67.10% ['weight_lbs', '3cone']
# Accuracy: 61.29% ['40yards', 'benchpress']
# Accuracy: 60.65% ['40yards', 'vert_leap_in']
# Accuracy: 59.35% ['40yards', 'broad_jump_in']
# Accuracy: 59.35% ['40yards', 'shuttle']
# Accuracy: 56.77% ['40yards', '3cone']
# Accuracy: 64.52% ['benchpress', 'vert_leap_in']
# Accuracy: 65.81% ['benchpress', 'broad_jump_in']
# Accuracy: 66.45% ['benchpress', 'shuttle']
# Accuracy: 66.45% ['benchpress', '3cone']
# Accuracy: 67.10% ['vert_leap_in', 'broad_jump_in']
# Accuracy: 67.10% ['vert_leap_in', 'shuttle']
# Accuracy: 63.87% ['vert_leap_in', '3cone']
# Accuracy: 65.81% ['broad_jump_in', 'shuttle']
# Accuracy: 65.16% ['broad_jump_in', '3cone']
# Accuracy: 61.94% ['shuttle', '3cone']
# Accuracy: 61.29% ['height_in', 'weight_lbs', '40yards']
# Accuracy: 65.16% ['height_in', 'weight_lbs', 'benchpress']
# Accuracy: 63.87% ['height_in', 'weight_lbs', 'vert_leap_in']
# Accuracy: 67.10% ['height_in', 'weight_lbs', 'broad_jump_in']
# Accuracy: 63.87% ['height_in', 'weight_lbs', 'shuttle']
# Accuracy: 63.23% ['height_in', 'weight_lbs', '3cone']
# Accuracy: 59.35% ['height_in', '40yards', 'benchpress']
# Accuracy: 58.06% ['height_in', '40yards', 'vert_leap_in']
# Accuracy: 58.71% ['height_in', '40yards', 'broad_jump_in']
# Accuracy: 57.42% ['height_in', '40yards', 'shuttle']
# Accuracy: 54.84% ['height_in', '40yards', '3cone']
# Accuracy: 64.52% ['height_in', 'benchpress', 'vert_leap_in']
# Accuracy: 63.87% ['height_in', 'benchpress', 'broad_jump_in']
# Accuracy: 64.52% ['height_in', 'benchpress', 'shuttle']
# Accuracy: 66.45% ['height_in', 'benchpress', '3cone']
# Accuracy: 68.39% ['height_in', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 64.52% ['height_in', 'vert_leap_in', 'shuttle']
# Accuracy: 62.58% ['height_in', 'vert_leap_in', '3cone']
# Accuracy: 65.16% ['height_in', 'broad_jump_in', 'shuttle']
# Accuracy: 63.23% ['height_in', 'broad_jump_in', '3cone']
# Accuracy: 62.58% ['height_in', 'shuttle', '3cone']
# Accuracy: 63.23% ['weight_lbs', '40yards', 'benchpress']
# Accuracy: 61.29% ['weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 62.58% ['weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 61.29% ['weight_lbs', '40yards', 'shuttle']
# Accuracy: 58.06% ['weight_lbs', '40yards', '3cone']
# Accuracy: 65.16% ['weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 65.16% ['weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 66.45% ['weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 69.03% ['weight_lbs', 'benchpress', '3cone']
# Accuracy: 67.74% ['weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 67.10% ['weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 63.23% ['weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 69.03% ['weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 67.10% ['weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 65.16% ['weight_lbs', 'shuttle', '3cone']
# Accuracy: 60.65% ['40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 62.58% ['40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 60.65% ['40yards', 'benchpress', 'shuttle']
# Accuracy: 59.35% ['40yards', 'benchpress', '3cone']
# Accuracy: 56.77% ['40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 56.77% ['40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 59.35% ['40yards', 'broad_jump_in', '3cone']
# Accuracy: 54.19% ['40yards', 'shuttle', '3cone']
# Accuracy: 67.74% ['benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 69.03% ['benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 63.87% ['benchpress', 'vert_leap_in', '3cone']
# Accuracy: 68.39% ['benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 65.81% ['benchpress', 'broad_jump_in', '3cone']
# Accuracy: 62.58% ['benchpress', 'shuttle', '3cone']
# Accuracy: 65.81% ['vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 64.52% ['vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 63.87% ['vert_leap_in', 'shuttle', '3cone']
# Accuracy: 65.81% ['broad_jump_in', 'shuttle', '3cone']
# Accuracy: 59.35% ['height_in', 'weight_lbs', '40yards', 'benchpress']
# Accuracy: 59.35% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 61.29% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'shuttle']
# Accuracy: 54.84% ['height_in', 'weight_lbs', '40yards', '3cone']
# Accuracy: 63.87% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 65.81% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 63.87% ['height_in', 'weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 67.10% ['height_in', 'weight_lbs', 'benchpress', '3cone']
# Accuracy: 69.68% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 63.23% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 61.94% ['height_in', 'weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 67.10% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 65.81% ['height_in', 'weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 63.23% ['height_in', 'weight_lbs', 'shuttle', '3cone']
# Accuracy: 58.71% ['height_in', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 62.58% ['height_in', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'shuttle']
# Accuracy: 59.35% ['height_in', '40yards', 'benchpress', '3cone']
# Accuracy: 58.06% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 56.13% ['height_in', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 54.84% ['height_in', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 60.65% ['height_in', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 59.35% ['height_in', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 56.13% ['height_in', '40yards', 'shuttle', '3cone']
# Accuracy: 64.52% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 67.10% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 65.81% ['height_in', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 67.10% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 63.87% ['height_in', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 66.45% ['height_in', 'benchpress', 'shuttle', '3cone']
# Accuracy: 65.16% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 65.16% ['height_in', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.29% ['height_in', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 62.58% ['height_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 62.58% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 65.16% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 62.58% ['weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 59.35% ['weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 61.29% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 58.06% ['weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 67.74% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 66.45% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 65.81% ['weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 70.32% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 69.68% ['weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 67.74% ['weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 65.16% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 66.45% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.29% ['weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.45% ['weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 58.06% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 56.13% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.65% ['40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 61.29% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 61.29% ['40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 59.35% ['40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 58.06% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 58.06% ['40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 57.42% ['40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 56.77% ['40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 66.45% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 67.10% ['benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.29% ['benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 64.52% ['benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 63.23% ['vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.29% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 60.65% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 65.16% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 56.77% ['height_in', 'weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 58.06% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 56.13% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 51.61% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 58.71% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 61.29% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 56.13% ['height_in', 'weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 67.74% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 62.58% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 64.52% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 68.39% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 67.10% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 67.10% ['height_in', 'weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 68.39% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.03% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 65.16% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.45% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 63.87% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 58.06% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 59.35% ['height_in', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 58.71% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 62.58% ['height_in', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 58.71% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 58.06% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 55.48% ['height_in', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 57.42% ['height_in', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.03% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.03% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 65.81% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.45% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 63.23% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.81% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 61.29% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 63.87% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 61.29% ['weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 58.06% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 59.35% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.16% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 69.03% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 61.94% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 68.39% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.16% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 56.13% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 61.94% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 58.06% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 58.71% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 54.84% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 65.81% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 64.52% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 56.77% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 63.23% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 62.58% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 61.29% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 58.06% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 58.71% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 54.19% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 58.71% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 66.45% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 68.39% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 66.45% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 66.45% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 67.74% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 59.35% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 61.29% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 58.71% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 58.06% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 56.77% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 71.61% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 61.29% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 62.58% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 59.35% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 61.94% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 57.42% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 67.10% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 56.13% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.65% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 62.58% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.65% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 62.58% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 59.35% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 69.68% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 56.77% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.65% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# 71.61290322580646

# %%
Accuracy: 71.61% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
