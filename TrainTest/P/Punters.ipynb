# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from numpy import sort
from sklearn.feature_selection import SelectFromModel

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

from itertools import combinations

# %%
df = pd.read_csv("../P-Train.csv")
df = df.drop(["year","name","college","position"],1)
df.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0      75.63         208     4.86         NaN           NaN            NaN
# 1      73.25         213     4.74        11.0          29.0          110.0
# 2      75.63         232     5.06        13.0           NaN            NaN
# 3      74.50         216     4.89         NaN          27.0            NaN
# 4      76.00         220     4.64        23.0          30.5            NaN
#
#    shuttle  3cone drafted
# 0      NaN    NaN       Y
# 1      NaN    NaN       N
# 2      NaN    NaN       N
# 3      NaN    NaN       N
# 4      NaN    NaN       Y

# %%
Y = df["drafted"]
Y = Y.replace("Y",1)
Y = Y.replace("N",0)

#X = df.drop(['weight_lbs', '3cone', 'Crec', 'Cyds', 'hasbling', 'hasawards', "drafted"], 1)
X = df.drop(["drafted"],1)

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 60.00%

# %%
def accuracyfinder(features):
    accuras = []
    
    Y = features["drafted"]
    Y = Y.replace("Y",1)
    Y = Y.replace("N",0)

    X = features.drop(["drafted"], 1)
    
    columns = X.columns.tolist()
    
    for a in range(1,len(columns)):
        for x in list(combinations(columns,a)):
            
            X = features.drop(["drafted"], 1)
            X = X.drop(list(x),1)
            # split data into train and test sets
            seed = 777
            test_size = 0.30
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

            # fit model on training data
            model = XGBClassifier()
            model.fit(X_train, y_train)

            # make predictions for test data
            y_pred = model.predict(X_test)
            predictions = [round(value) for value in y_pred]

            # evaluate predictions
            accuracy = accuracy_score(y_test, predictions)
            accuras.append(accuracy * 100)
            print("Accuracy: %.2f%%" % (accuracy * 100.0), list(x))
    
    
    print(max(accuras))

# %%
accuracyfinder(df)
# Out:
# Accuracy: 60.00% ['height_in']
# Accuracy: 60.00% ['weight_lbs']
# Accuracy: 60.00% ['40yards']
# Accuracy: 60.00% ['benchpress']
# Accuracy: 60.00% ['vert_leap_in']
# Accuracy: 60.00% ['broad_jump_in']
# Accuracy: 60.00% ['shuttle']
# Accuracy: 60.00% ['3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs']
# Accuracy: 60.00% ['height_in', '40yards']
# Accuracy: 60.00% ['height_in', 'benchpress']
# Accuracy: 60.00% ['height_in', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards']
# Accuracy: 60.00% ['weight_lbs', 'benchpress']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in']
# Accuracy: 60.00% ['weight_lbs', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress']
# Accuracy: 60.00% ['40yards', 'vert_leap_in']
# Accuracy: 60.00% ['40yards', 'broad_jump_in']
# Accuracy: 60.00% ['40yards', 'shuttle']
# Accuracy: 60.00% ['40yards', '3cone']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['benchpress', 'shuttle']
# Accuracy: 60.00% ['benchpress', '3cone']
# Accuracy: 60.00% ['vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['vert_leap_in', '3cone']
# Accuracy: 60.00% ['broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['broad_jump_in', '3cone']
# Accuracy: 60.00% ['shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', '40yards', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', '40yards', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['height_in', 'benchpress', '3cone']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['40yards', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['40yards', 'benchpress', '3cone']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['40yards', 'shuttle', '3cone']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'benchpress', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', '40yards', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', 'weight_lbs', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['height_in', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# Accuracy: 60.00% ['weight_lbs', '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle', '3cone']
# 60.0
