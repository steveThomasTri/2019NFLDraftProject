# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_NFL_combine_97_to_2018.csv")
df.head()
# Out:
#    year              name     college position  height_in  weight_lbs  \
# 0  1997        mike adams       Texas       WR       71.4         184
# 1  1997  winston alderson    Arkansas       OT       76.1         344
# 2  1997        ink aleaga  Washington      ILB       73.0         227
# 3  1997        eric allen     Indiana       FS       72.0         205
# 4  1997       james allen    Oklahoma       RB       70.1         212
#
#    40yards  benchpress  vert_leap_in  broad_jump_in  shuttle  3cone drafted
# 0     4.59         NaN          29.5          112.0     4.38   7.51       N
# 1     5.60         NaN          24.5           92.0     5.25   8.85       N
# 2     4.87         NaN          31.0          107.0     4.33   7.60       N
# 3     4.78         NaN          34.0          116.0     4.22   7.27       N
# 4      NaN        11.0          31.0            NaN      NaN    NaN       N

# %%
df.describe()
# Out:
#               year    height_in   weight_lbs      40yards   benchpress  \
# count  6300.000000  6300.000000  6300.000000  6083.000000  4708.000000
# mean   2007.567302    73.890240   244.927937     4.806699    20.898046
# std       6.367863     2.619497    45.465938     0.313590     6.328704
# min    1997.000000    65.250000   155.000000     4.210000     2.000000
# 25%    2002.000000    72.000000   207.000000     4.560000    16.000000
# 50%    2008.000000    74.000000   236.000000     4.730000    21.000000
# 75%    2013.000000    75.900000   286.000000     5.010000    25.000000
# max    2018.000000    81.630000   387.000000     6.120000    51.000000
#
#        vert_leap_in  broad_jump_in      shuttle        3cone
# count   5505.000000    5390.000000  4769.000000  4640.000000
# mean      32.682834     113.269388     4.386066     7.340519
# std        4.186874       9.287224     0.269184     0.446217
# min       17.500000      73.000000     3.730000     6.340000
# ...

# %%
#find all correlations

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col0 {
#             background-color:  #b40426;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col1 {
#             background-color:  #9fbfff;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col2 {
#             background-color:  #bfd3f6;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col3 {
#             background-color:  #bcd2f7;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col4 {
#             background-color:  #8badfd;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col5 {
#             background-color:  #c9d7f0;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col6 {
#             background-color:  #e8d6cc;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col7 {
#             background-color:  #cfdaea;
#         }    #T_fd0bf040_5674_11e9_b8a2_d0bf9c9d8a3erow0_col8 {
#             background-color:  #90b2fe;
# ...

# %%
#here we have 28 pairs of features that we want to explore (keep in mind that they)

# %%
corr2 = df.corr()
corr2
# Out:
#                    year  height_in  weight_lbs   40yards  benchpress  \
# year           1.000000   0.001294   -0.025223 -0.109306   -0.033502
# height_in      0.001294   1.000000    0.722126  0.616437    0.373361
# weight_lbs    -0.025223   0.722126    1.000000  0.858913    0.625783
# 40yards       -0.109306   0.616437    0.858913  1.000000    0.452183
# benchpress    -0.033502   0.373361    0.625783  0.452183    1.000000
# vert_leap_in  -0.001342  -0.428117   -0.633351 -0.750089   -0.309988
# broad_jump_in  0.169125  -0.428641   -0.696255 -0.819220   -0.368407
# shuttle        0.068368   0.524520    0.761049  0.780747    0.381913
# 3cone         -0.268573   0.473585    0.740057  0.793931    0.372272
#
#                vert_leap_in  broad_jump_in   shuttle     3cone
# year              -0.001342       0.169125  0.068368 -0.268573
# height_in         -0.428117      -0.428641  0.524520  0.473585
# weight_lbs        -0.633351      -0.696255  0.761049  0.740057
# ...

# %%
# + vertical leap & broad jump .804956
# + weight_lbs & 40 yards .858913
# + 3cone & shuttle .790662
# - broad_jump_in & 40 yards -.819220

# %%
df[df["40yards"].isnull()].head()
# Out:
#     year            name             college position  height_in  weight_lbs  \
# 4   1997     james allen            Oklahoma       RB       70.1         212
# 10  1997   darnell autry        Northwestern       RB       70.8         210
# 20  1997  michael booker            Nebraska       CB       73.3         203
# 32  1997    chris carter               Texas       FS       73.3         200
# 43  1997   damion cooper  Central State (OH)       DE       75.4         260
#
#     40yards  benchpress  vert_leap_in  broad_jump_in  shuttle  3cone drafted
# 4       NaN        11.0          31.0            NaN      NaN    NaN       N
# 10      NaN         NaN          34.0          114.0      NaN    NaN       Y
# 20      NaN        10.0           NaN            NaN      NaN    NaN       Y
# 32      NaN        16.0           NaN            NaN      NaN    NaN       Y
# 43      NaN        25.0          29.5          112.0      NaN    NaN       N

# %%
df.groupby(["position", "drafted"])["40yards"].describe()
# Out:
#                   count      mean       std   min     25%    50%     75%   max
# position drafted
# C        N         77.0  5.275714  0.193822  4.82  5.1700  5.250  5.4000  5.84
#          Y         99.0  5.247475  0.148016  4.89  5.1500  5.250  5.3300  5.64
# CB       N        174.0  4.564080  0.099664  4.33  4.4900  4.570  4.6300  4.95
#          Y        427.0  4.487190  0.084501  4.25  4.4300  4.490  4.5400  4.78
# DB       N          1.0  4.620000       NaN  4.62  4.6200  4.620  4.6200  4.62
#          Y          3.0  4.466667  0.080829  4.38  4.4300  4.480  4.5100  4.54
# DE       N        143.0  4.917483  0.136513  4.53  4.8200  4.920  5.0000  5.27
#          Y        365.0  4.819397  0.132162  4.48  4.7300  4.820  4.9000  5.26
# DL       N          1.0  4.880000       NaN  4.88  4.8800  4.880  4.8800  4.88
#          Y          3.0  4.756667  0.040415  4.72  4.7350  4.750  4.7750  4.80
# DT       N        153.0  5.153922  0.169827  4.77  5.0300  5.150  5.2700  5.77
# ...
