# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cleaned_NFL_combine_97_to_2018.csv")
df
# Out:
#       year                  name                  college position  height_in  \
# 0     1997            mike adams                    Texas       WR       71.4
# 1     1997      winston alderson                 Arkansas       OT       76.1
# 2     1997            ink aleaga               Washington      ILB       73.0
# 3     1997            eric allen                  Indiana       FS       72.0
# 4     1997           james allen                 Oklahoma       RB       70.1
# 5     1997           john allred      Southern California       TE       76.4
# 6     1997      richard alvarado       Jackson State (MS)      OLB       74.6
# 7     1997         jim arellanes        Frenso State (CA)       QB       75.1
# 8     1997          duane ashman                 Virginia       DE       75.5
# 9     1997        raymond austin                Tennessee       SS       70.6
# 10    1997         darnell autry             Northwestern       RB       70.8
# ...

# %%
df[(df["position"] == "SS") | (df["position"] == "FS")].to_csv("TrainTest/S-Train.csv", index=False)

# %%
#These are the ten csvs that we will be generating
df[(df["position"] == "OT") | (df["position"] == "OG") | (df["position"] == "C") | (df["position"] == "OL")].to_csv("TrainTest/OL-Train.csv", index=False)
df[(df["position"] == "DT") | (df["position"] == "DE") | (df["position"] == "DL")].to_csv("TrainTest/DL-Train.csv", index=False)
df[(df["position"] == "RB") | (df["position"] == "HB") | (df["position"] == "FB")].to_csv("TrainTest/RFBacks-Train.csv", index=False)
df[(df["position"] == "OLB") | (df["position"] == "ILB") | (df["position"] == "LB") | (df["position"] == "DB")].to_csv("TrainTest/DBacks-Train.csv", index=False)
df[(df["position"] == "TE")].to_csv("TrainTest/TE-Train.csv", index=False)
df[(df["position"] == "CB")].to_csv("TrainTest/CB-Train.csv", index=False)
df[(df["position"] == "WR")].to_csv("TrainTest/WR-Train.csv", index=False)
df[(df["position"] == "SS") | (df["position"] == "FS")].to_csv("TrainTest/S-Train.csv", index=False)
df[(df["position"] == "QB")].to_csv("TrainTest/QB-Train.csv", index=False)
df[(df["position"] == "P")].to_csv("TrainTest/P-Train.csv", index=False)
